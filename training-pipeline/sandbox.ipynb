# %%
with open('flowers.jsonl', 'w') as file:
    dataset = tf.data.TextLineDataset(IMPORT_FILE)
    for line in dataset:
        file.write(json.dumps(ast.literal_eval(str(line.numpy(), 'utf-8'))))
        file.write('\n')

# %%
# !gsutil cat gs://cloud-samples-data/ai-platform/flowers/train_set.csv | wc -l
# Out:
# 3300

# %%
for record in dataset.take(1):
    print(record)
    parsed = tfio.experimental.serialization.decode_json(record, specs)
    print(parsed)
# Out:
# tf.Tensor(b'{"imageGcsUri": "gs://ucaip-test-us-central1/dataset/image/flower/roses/10090824183_d02c613f10_m.jpg", "classificationAnnotation": {"displayName": "roses"}, "dataItemResourceLabels": {"aiplatform.googleapis.com/ml_use": "training"}}', shape=(), dtype=string)
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-191-ff5f650c3b1c> in <module>
#       1 for record in dataset.take(1):
#       2     print(record)
# ----> 3     parsed = tfio.experimental.serialization.decode_json(record, specs)
#       4     print(parsed)
#
# /opt/conda/lib/python3.7/site-packages/tensorflow_io/core/python/experimental/serialization_ops.py in decode_json(data, specs, name)
#      74     dtypes = [e.dtype for e in named]
#      75
# ---> 76     values = core_ops.io_decode_json(data, names, dtypes, name=name)
#      77     values = [tf.reshape(value, shape) for value, shape in zip(values, shapes)]
#      78     return tf.nest.pack_sequence_as(specs, values)
#
# <string> in io_decode_json(input, names, dtypes, name)
#
# <string> in io_decode_json_eager_fallback(input, names, dtypes, name, ctx)
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# InvalidArgumentError: no value for /dataItemResurceLabels/aiplatform.googleapis.com\/ml_use [Op:IO>DecodeJSON]

# %%
specs = {
        'imageGcsUri': tf.TensorSpec(tf.TensorShape([]), tf.string),
        'classificationAnnotation': {
            'displayName': tf.TensorSpec(tf.TensorShape([]), tf.string)
        },
        'dataItemResurceLabels': {
            'aiplatform.googleapis.com\/ml_use': tf.TensorSpec(tf.TensorShape([]), tf.string)
        }
    }

dataset = tf.data.TextLineDataset('flowers.jsonl')

# %%
for record in dataset.take(1):
    print(record)
    parsed = tfio.experimental.serialization.decode_json(record, specs)
    print(parsed)
# Out:
# tf.Tensor(b'{"imageGcsUri": "gs://ucaip-test-us-central1/dataset/image/flower/roses/10090824183_d02c613f10_m.jpg", "classificationAnnotation": {"displayName": "roses"}, "dataItemResourceLabels": {"aiplatform.googleapis.com/ml_use": "training"}}', shape=(), dtype=string)
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-191-ff5f650c3b1c> in <module>
#       1 for record in dataset.take(1):
#       2     print(record)
# ----> 3     parsed = tfio.experimental.serialization.decode_json(record, specs)
#       4     print(parsed)
#
# /opt/conda/lib/python3.7/site-packages/tensorflow_io/core/python/experimental/serialization_ops.py in decode_json(data, specs, name)
#      74     dtypes = [e.dtype for e in named]
#      75
# ---> 76     values = core_ops.io_decode_json(data, names, dtypes, name=name)
#      77     values = [tf.reshape(value, shape) for value, shape in zip(values, shapes)]
#      78     return tf.nest.pack_sequence_as(specs, values)
#
# <string> in io_decode_json(input, names, dtypes, name)
#
# <string> in io_decode_json_eager_fallback(input, names, dtypes, name, ctx)
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# InvalidArgumentError: no value for /dataItemResurceLabels/aiplatform.googleapis.com\/ml_use [Op:IO>DecodeJSON]

# %%
IMPORT_FILE = 'gs://cloud-samples-data/vision/automl_classification/flowers/flowers-50.jsonl'

# %%
specs = {
        'imageGcsUri': tf.TensorSpec(tf.TensorShape([]), tf.string)
    }

# %%
tf.TensorShape([]).rank

# %%
parsed = tfio.experimental.serialization.decode_json(json_text, specs)

# %%
parsed = tfio.experimental.serialization.decode_json(json_text, specs)

# %%
import pandas as pd

df = pd.read_json('flowers.jsonl', lines=True)

# %%
pd.json_normalize(df['dataItemResourceLabels']).values
# Out:
# array([['training'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['test'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['validation'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['validation'],
#        ['test'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['validation'],
#        ['test'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['validation'],
#        ['test'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['training'],
#        ['validation'],
#        ['test']], dtype=object)

# %%
df['dataItemResourceLabels'].apply(pd.Series)
# Out:
#    aiplatform.googleapis.com/ml_use
# 0                          training
# 1                          training
# 2                          training
# 3                          training
# 4                          training
# 5                          training
# 6                              test
# 7                          training
# 8                          training
# 9                          training
# 10                         training
# 11                       validation
# 12                         training
# 13                         training
# 14                         training
# 15                         training
# 16                         training
# 17                         training
# 18                         training
# 19                         training
# 20                       validation
# 21                             test
# 22                         training
# 23                         training
# 24                         training
# 25                         training
# 26                         training
# 27                       validation
# 28                             test
# 29                         training
# 30                         training
# 31                         training
# 32                         training
# 33                         training
# 34                       validation
# 35                             test
# 36                         training
# 37                         training
# 38                         training
# 39                         training
# 40                         training
# 41                         training
# 42                         training
# 43                         training
# 44                         training
# 45                         training
# 46                         training
# 47                         training
# 48                       validation
# 49                             test

# %%
for item in df['dataItemResourceLabels']:
    print(item['aiplatform.googleapis.com/ml_use'])
# Out:
# training
# training
# training
# training
# training
# training
# test
# training
# training
# training
# training
# validation
# training
# training
# training
# training
# training
# training
# training
# training
# validation
# test
# training
# training
# training
# training
# training
# validation
# test
# training
# training
# training
# training
# training
# validation
# test
# training
# training
# training
# training
# training
# training
# training
# training
# training
# training
# training
# training
# validation
# test
